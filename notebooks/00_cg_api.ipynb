# %% [markdown]
# # Exploration
#
# This will be a short messy notebook where I explore the CoinGecko API

# %%
from bs4 import BeautifulSoup
from pycoingecko import CoinGeckoAPI
import pandas as pd
from datetime import datetime
import json

# %%
cg = CoinGeckoAPI()
dir(cg)
# Out:
# ['_CoinGeckoAPI__API_URL_BASE',
#  '_CoinGeckoAPI__api_url_params',
#  '_CoinGeckoAPI__request',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'api_base_url',
#  'get_coin_by_id',
#  'get_coin_history_by_id',
#  'get_coin_info_from_contract_address_by_id',
#  'get_coin_market_chart_by_id',
#  'get_coin_market_chart_from_contract_address_by_id',
#  'get_coin_market_chart_range_by_id',
#  'get_coin_market_chart_range_from_contract_address_by_id',
#  'get_coin_ohlc_by_id',
#  'get_coin_status_updates_by_id',
#  'get_coin_ticker_by_id',
#  'get_coins',
#  'get_coins_list',
#  'get_coins_markets',
# ...

# %%
cg.ping()
# Out:
# {'gecko_says': '(V3) To the Moon!'}

# %%
sample_return = cg.get_coins()[0]

# %%
sample_return
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'block_time_in_minutes': '10.0',
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579',
#   'large': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579'},
#  'market_data': {'current_price': {'aed': 58077,
#    'ars': 1260518,
#    'aud': 21747,
#    'bch': 66.018,
#    'bdt': 1342071,
#    'bhd': 5961.89,
#    'bmd': 15812.14,
#    'bnb': 581.184,
#    'brl': 86369,
#    'btc': 1.0,
#    'cad': 20771,
#    'chf': 14437.37,
#    'clp': 12129468,
#    'cny': 104461,
#    'czk': 353037,
#    'dkk': 99554,
#    'dot': 3646,
#    'eos': 6389,
#    'eth': 35.787804,
#    'eur': 13357.68,
#    'gbp': 11999.83,
#    'hkd': 122599,
#    'huf': 4772878,
#    'idr': 223540550,
#    'ils': 53262,
#    'inr': 1178604,
#    'jpy': 1655713,
#    'krw': 17519904,
#    'kwd': 4833.77,
# ...

# %%
len(cg.get_coins())
# Out:
# 50

# %%
current_prices_usd = {coin['symbol']: coin['market_data']['current_price']['usd'] for coin in cg.get_coins()}
current_prices_usd
# Out:
# {'btc': 16764.02,
#  'eth': 461.57,
#  'usdt': 0.999862,
#  'xrp': 0.284095,
#  'link': 12.62,
#  'ltc': 70.99,
#  'bch': 248.34,
#  'dot': 4.47,
#  'bnb': 28.02,
#  'ada': 0.103948,
#  'bsv': 158.49,
#  'usdc': 0.998681,
#  'eos': 2.57,
#  'xmr': 117.61,
#  'wbtc': 16741.07,
#  'trx': 0.02545319,
#  'xlm': 0.081796,
#  'cdai': 0.02086183,
#  'xtz': 2.07,
#  'cro': 0.06558,
#  'okb': 4.62,
#  'xem': 0.13671,
#  'leo': 1.25,
#  'atom': 5.1,
#  'neo': 15.71,
#  'dai': 1.0,
#  'fil': 27.52,
#  'aave': 71.14,
#  'ht': 3.54,
#  'dash': 80.74,
#  'uni': 3.51,
#  'vet': 0.01129017,
#  'cel': 1.9,
#  'miota': 0.255665,
#  'zec': 65.89,
#  'busd': 0.999503,
#  'etc': 5.33,
#  'theta': 0.618553,
#  'snx': 4.4,
#  'yfi': 18332.4,
#  'ceth': 9.25,
#  'waves': 4.86,
#  'omg': 3.43,
#  'comp': 120.35,
#  'mkr': 518.89,
#  'uma': 8.09,
#  'pax': 0.998383,
#  'ont': 0.473937,
#  'doge': 0.00287734,
#  'cusdc': 0.0212092}

# %%
len(current_prices_usd)
# Out:
# 50

# %%
datetime.now().strftime("%d/%m/%Y %H:%M:%S")
# Out:
# '16/11/2020 12:08:30'
